# %% [markdown]
# # Testing Moderation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("addhealth_pds.csv",low_memory=False)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
pd.set_option('display.float_format',lambda x: '%f'%x)

# %%
data['H1PF29'] = pd.to_numeric(data['H1PF29'])
data['H1PF30']=pd.to_numeric(data['H1PF30'])
data['H1PF31']=pd.to_numeric(data['H1PF31'])
data['H1PF32']=pd.to_numeric(data['H1PF32'])
data['H1PF33']=pd.to_numeric(data['H1PF33'])
data['H1PF34']=pd.to_numeric(data['H1PF34'])
data['H1PF35']=pd.to_numeric(data['H1PF35'])
data['H1PF36']=pd.to_numeric(data['H1PF36'])
data['H1ED20']=pd.to_numeric(data['H1ED20'])
data['H1ED18']=pd.to_numeric(data['H1ED18'])

# %%
data2=data.copy()
data2['H1PF30']=data2['H1PF30'].replace(3,np.nan)
data2['H1PF30']=data2['H1PF30'].replace(6,np.nan)
data2['H1PF30']=data2['H1PF30'].replace(8,np.nan)

data2['H1PF32']=data2['H1PF32'].replace(3,np.nan)
data2['H1PF32']=data2['H1PF32'].replace(6,np.nan)
data2['H1PF32']=data2['H1PF32'].replace(8,np.nan)

data2['H1PF33']=data2['H1PF33'].replace(3,np.nan)
data2['H1PF33']=data2['H1PF33'].replace(6,np.nan)
data2['H1PF33']=data2['H1PF33'].replace(8,np.nan)

data2['H1PF34']=data2['H1PF34'].replace(3,np.nan)
data2['H1PF34']=data2['H1PF34'].replace(6,np.nan)
data2['H1PF34']=data2['H1PF34'].replace(8,np.nan)

data2['H1PF35']=data2['H1PF35'].replace(3,np.nan)
data2['H1PF35']=data2['H1PF35'].replace(6,np.nan)
data2['H1PF35']=data2['H1PF35'].replace(8,np.nan)

data2['H1PF36']=data2['H1PF36'].replace(3,np.nan)
data2['H1PF36']=data2['H1PF36'].replace(6,np.nan)
data2['H1PF36']=data2['H1PF36'].replace(8,np.nan)

# %%
data2['H1ED18']=data2['H1ED18'].replace(3,np.nan)
data2['H1ED18']=data2['H1ED18'].replace(6,np.nan)
data2['H1ED18']=data2['H1ED18'].replace(7,np.nan)
data2['H1ED18']=data2['H1ED18'].replace(8,np.nan)

data2['H1ED20']=data2['H1ED20'].replace(3,np.nan)
data2['H1ED20']=data2['H1ED20'].replace(6,np.nan)
data2['H1ED20']=data2['H1ED20'].replace(7,np.nan)
data2['H1ED20']=data2['H1ED20'].replace(8,np.nan)

# %%
recode={1:5,2:4,4:2,5:1}

# %%
data2['H1PF30FREQ']=data['H1PF30'].map(recode)
data2['H1PF32FREQ']=data['H1PF32'].map(recode)
data2['H1PF33FREQ']=data['H1PF33'].map(recode)
data2['H1PF34FREQ']=data['H1PF34'].map(recode)
data2['H1PF35FREQ']=data['H1PF35'].map(recode)
data2['H1PF36FREQ']=data['H1PF36'].map(recode)
data2['H1ED18FREQ']=data['H1ED18'].map(recode)
data2['H1ED20FREQ']=data['H1ED20'].map(recode)

# %%
data2['H1PF30FREQ']=data2['H1PF30FREQ'].astype('category')
data2['H1PF32FREQ']=data2['H1PF32FREQ'].astype('category')
data2['H1PF33FREQ']=data2['H1PF33FREQ'].astype('category')
data2['H1PF34FREQ']=data2['H1PF34FREQ'].astype('category')
data2['H1PF35FREQ']=data2['H1PF35FREQ'].astype('category')
data2['H1PF36FREQ']=data2['H1PF36FREQ'].astype('category')

data2['H1ED18FREQ']=data2['H1ED18FREQ'].astype('category')
data2['H1ED20FREQ']=data2['H1ED20FREQ'].astype('category')

# %%
def H1PF30FREQResponse(row):
    if row['H1PF30FREQ']==4 or row['H1PF30FREQ']==5:
        return 1
    else:
        return 0
def H1PF32FREQResponse(row):
    if row['H1PF32FREQ']==4 or row['H1PF32FREQ']==5:
        return 1
    else:
        return 0
    
def H1PF33FREQResponse(row):
    if row['H1PF33FREQ']==4 or row['H1PF33FREQ']==5:
        return 1
    else:
        return 0
    
def H1PF34FREQResponse(row):
    if row['H1PF34FREQ']==4 or row['H1PF34FREQ']==5:
        return 1
    else:
        return 0
def H1PF36FREQResponse(row):
    if row['H1PF36FREQ']==4 or row['H1PF36FREQ']==5:
        return 1
    else:
        return 0

# %%
data2['H1PF30FREQResponse']=data2.apply(lambda row:H1PF30FREQResponse(row),axis=1)
data2['H1PF32FREQResponse']=data2.apply(lambda row:H1PF32FREQResponse(row),axis=1)
data2['H1PF33FREQResponse']=data2.apply(lambda row:H1PF33FREQResponse(row),axis=1)
data2['H1PF34FREQResponse']=data2.apply(lambda row:H1PF34FREQResponse(row),axis=1)
data2['H1PF36FREQResponse']=data2.apply(lambda row:H1PF36FREQResponse(row),axis=1)

# %%
import scipy.stats

# %% [markdown]
# Creating two datasets for H1FS6(Answer to the question 'are you depressed?'), data3 for H1FS6 being 0(never or rarely depressed), data4 for H1FS6 being 3(most of the time or all the time), being 2 (a lot of times) and being 1(sometimes).

# %%
data3=data2[(data2['H1FS6']==0)]
data3=data2[(data2['H1FS6']==1) |(data2['H1FS6']==2)|(data2['H1FS6']==3) ]

# %% [markdown]
# ChiSquare Tests with Testing Moderation

# %%
ct1=pd.crosstab(data3['H1PF30FREQResponse'],data3['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                          2        12       112        12
# 1                          4        62      2177      1309
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.333333  0.162162  0.048930  0.009084
# 1                   0.666667  0.837838  0.951070  0.990916
# chi-square value, p value, expected counts
# (84.46638850980278, 3.3782523651468452e-18, 3, array([[2.24390244e-01, 2.76747967e+00, 8.56048780e+01, 4.94032520e+01],
#        [5.77560976e+00, 7.12325203e+01, 2.20339512e+03, 1.27159675e+03]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF30FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF30FREQResponse'],data4['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                         10        52       144        21
# 1                         24       115      1240       514
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.294118  0.311377  0.104046  0.039252
# 1                   0.705882  0.688623  0.895954  0.960748
# chi-square value, p value, expected counts
# (111.21832597255637, 5.9996945758849424e-24, 3, array([[   3.64056604,   17.88160377,  148.19245283,   57.28537736],
#        [  30.35943396,  149.11839623, 1235.80754717,  477.71462264]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF30FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF32FREQResponse'],data3['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                          2        13       109        15
# 1                          4        61      2180      1306
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.333333  0.175676  0.047619  0.011355
# 1                   0.666667  0.824324  0.952381  0.988645
# chi-square value, p value, expected counts
# (84.83242216809695, 2.8192034939213913e-18, 3, array([[2.26016260e-01, 2.78753388e+00, 8.62252033e+01, 4.97612466e+01],
#        [5.77398374e+00, 7.12124661e+01, 2.20277480e+03, 1.27123875e+03]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF32FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF32FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF32FREQResponse'],data4['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                         16        60       168        24
# 1                         18       107      1216       511
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.470588  0.359281  0.121387  0.044860
# 1                   0.529412  0.640719  0.878613  0.955140
# chi-square value, p value, expected counts
# (151.01059226345828, 1.5949908171101255e-32, 3, array([[   4.29811321,   21.11132075,  174.95849057,   67.63207547],
#        [  29.70188679,  145.88867925, 1209.04150943,  467.36792453]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF32FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(6.799999999999997, 0.5, 'H1PF32FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF33FREQResponse'],data3['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                          2        31       371        71
# 1                          4        43      1918      1250
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.333333  0.418919  0.162080  0.053747
# 1                   0.666667  0.581081  0.837920  0.946253
# chi-square value, p value, expected counts
# (146.72187427598638, 1.342355695360536e-31, 3, array([[7.72357724e-01, 9.52574526e+00, 2.94654472e+02, 1.70047425e+02],
#        [5.22764228e+00, 6.44742547e+01, 1.99434553e+03, 1.15095257e+03]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF32FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF33FREQResponse'],data4['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                         26       105       445        75
# 1                          8        62       939       460
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.764706  0.628743  0.321532  0.140187
# 1                   0.235294  0.371257  0.678468  0.859813
# chi-square value, p value, expected counts
# (186.0599093610137, 4.331976846235668e-40, 3, array([[ 10.44056604,  51.28160377, 424.99245283, 164.28537736],
#        [ 23.55943396, 115.71839623, 959.00754717, 370.71462264]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF33FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(6.799999999999997, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF34FREQResponse'],data3['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                          3        38       574       129
# 1                          3        36      1715      1192
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.500000  0.513514  0.250765  0.097653
# 1                   0.500000  0.486486  0.749235  0.902347
# chi-square value, p value, expected counts
# (171.08382135312212, 7.424741765731737e-37, 3, array([[1.20975610e+00, 1.49203252e+01, 4.61521951e+02, 2.66347967e+02],
#        [4.79024390e+00, 5.90796748e+01, 1.82747805e+03, 1.05465203e+03]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF34FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(6.799999999999997, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF34FREQResponse'],data4['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                         26       123       577        99
# 1                          8        44       807       436
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.764706  0.736527  0.416908  0.185047
# 1                   0.235294  0.263473  0.583092  0.814953
# chi-square value, p value, expected counts
# (203.1904242709284, 8.625285502111592e-44, 3, array([[ 13.23113208,  64.98820755, 538.58490566, 208.19575472],
#        [ 20.76886792, 102.01179245, 845.41509434, 326.80424528]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF34FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(6.799999999999997, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF36FREQResponse'],data3['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                          2        28        90        14
# 1                          4        46      2199      1307
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.333333  0.378378  0.039318  0.010598
# 1                   0.666667  0.621622  0.960682  0.989402
# chi-square value, p value, expected counts
# (288.0980330101726, 3.7455612122134873e-62, 3, array([[2.17886179e-01, 2.68726287e+00, 8.31235772e+01, 4.79712737e+01],
#        [5.78211382e+00, 7.13127371e+01, 2.20587642e+03, 1.27302873e+03]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF36FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF36FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF36FREQResponse'],data4['H1PF35FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                         22        81       162        19
# 1                         12        86      1222       516
# H1PF35FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.647059  0.485030  0.117052  0.035514
# 1                   0.352941  0.514970  0.882948  0.964486
# chi-square value, p value, expected counts
# (302.66960216987513, 2.630166662910685e-65, 3, array([[   4.55471698,   22.37169811,  185.40377358,   71.66981132],
#        [  29.44528302,  144.62830189, 1198.59622642,  463.33018868]]))

# %%
sns.factorplot(x="H1PF35FREQ", y="H1PF36FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1PF35FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(6.799999999999997, 0.5, 'H1PF36FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF30FREQResponse'],data3['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                          6        12        96
# 1                         86       228      1629
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.065217  0.050000  0.055652
# 1                   0.934783  0.950000  0.944348
# chi-square value, p value, expected counts
# (0.3051495304979092, 0.8584947059864905, 2, array([[   5.09868741,   13.30092368,   95.60038892],
#        [  86.90131259,  226.69907632, 1629.39961108]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF30FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(-5.825000000000003, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF30FREQResponse'],data4['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                         14        44       173
# 1                        101       229       956
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.121739  0.161172  0.153233
# 1                   0.878261  0.838828  0.846767
# chi-square value, p value, expected counts
# (1.00612239188063, 0.604676789497139, 2, array([[ 17.51153593,  41.57086355, 171.91760053],
#        [ 97.48846407, 231.42913645, 957.08239947]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF30FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(-5.825000000000003, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF32FREQResponse'],data3['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                          8        18        86
# 1                         84       222      1639
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.086957  0.075000  0.049855
# 1                   0.913043  0.925000  0.950145
# chi-square value, p value, expected counts
# (4.564309166546915, 0.10206406411755173, 2, array([[   5.00923675,   13.06757414,   93.92318911],
#        [  86.99076325,  226.93242586, 1631.07681089]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF32FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(-5.950000000000003, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF32FREQResponse'],data4['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                         18        60       179
# 1                         97       213       950
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.156522  0.219780  0.158547
# 1                   0.843478  0.780220  0.841453
# chi-square value, p value, expected counts
# (6.0049033487857795, 0.04966515619279317, 2, array([[ 19.48253131,  46.2498352 , 191.26763349],
#        [ 95.51746869, 226.7501648 , 937.73236651]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF32FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF32FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF33FREQResponse'],data3['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                         11        46       291
# 1                         81       194      1434
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.119565  0.191667  0.168696
# 1                   0.880435  0.808333  0.831304
# chi-square value, p value, expected counts
# (2.4775014155687898, 0.2897459693093765, 2, array([[  15.5644142 ,   40.60281964,  291.83276616],
#        [  76.4355858 ,  199.39718036, 1433.16723384]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF33FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5499999999999972, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF33FREQResponse'],data4['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                         36       114       432
# 1                         79       159       697
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.313043  0.417582  0.382640
# 1                   0.686957  0.582418  0.617360
# chi-square value, p value, expected counts
# (3.7587033986503084, 0.15268906209868652, 2, array([[ 44.11997363, 104.73698088, 433.14304548],
#        [ 70.88002637, 168.26301912, 695.85695452]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF33FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF34FREQResponse'],data3['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                         25        74       439
# 1                         67       166      1286
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.271739  0.308333  0.254493
# 1                   0.728261  0.691667  0.745507
# chi-square value, p value, expected counts
# (3.213983454161553, 0.20048983594115954, 2, array([[  24.06222654,   62.77102577,  451.16674769],
#        [  67.93777346,  177.22897423, 1273.83325231]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF34FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF34FREQResponse'],data4['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                         46       150       524
# 1                         69       123       605
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.400000  0.549451  0.464128
# 1                   0.600000  0.450549  0.535872
# chi-square value, p value, expected counts
# (9.196990312762686, 0.010066973572684948, 2, array([[ 54.58141068, 129.57152274, 535.84706658],
#        [ 60.41858932, 143.42847726, 593.15293342]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF34FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF36FREQResponse'],data3['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                          7        25        91
# 1                         85       215      1634
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.076087  0.104167  0.052754
# 1                   0.923913  0.895833  0.947246
# chi-square value, p value, expected counts
# (10.36048424431965, 0.005626643914287892, 2, array([[   5.50121536,   14.3509966 ,  103.14778804],
#        [  86.49878464,  225.6490034 , 1621.85221196]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF36FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF36FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF36FREQResponse'],data4['H1ED18FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                         25        64       191
# 1                         90       209       938
# H1ED18FREQ          2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.217391  0.234432  0.169176
# 1                   0.782609  0.765568  0.830824
# chi-square value, p value, expected counts
# (7.1103853406591915, 0.028575868663818553, 2, array([[ 21.22610415,  50.38892551, 208.38497034],
#        [ 93.77389585, 222.61107449, 920.61502966]]))

# %%
sns.factorplot(x="H1ED18FREQ", y="H1PF36FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED18FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF36FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF30FREQResponse'],data3['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                         12        20        97        27
# 1                         75       238      1852      1116
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.137931  0.077519  0.049769  0.023622
# 1                   0.862069  0.922481  0.950231  0.976378
# chi-square value, p value, expected counts
# (36.704999377061654, 5.312461993289358e-08, 3, array([[   3.94879255,   11.71021239,   88.46203084,   51.87896421],
#        [  83.05120745,  246.28978761, 1860.53796916, 1091.12103579]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF30FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF30FREQResponse'],data4['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                         29        60       134        34
# 1                         89       244       953       498
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF30FREQResponse
# 0                   0.245763  0.197368  0.123275  0.063910
# 1                   0.754237  0.802632  0.876725  0.936090
# chi-square value, p value, expected counts
# (48.15342526104022, 1.9752573574886723e-10, 3, array([[ 14.85840274,  38.27927487, 136.87359138,  66.98873101],
#        [103.14159726, 265.72072513, 950.12640862, 465.01126899]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF30FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF30FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(-5.950000000000003, 0.5, 'H1PF30FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF32FREQResponse'],data3['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                         15        31        81        27
# 1                         72       227      1868      1116
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.172414  0.120155  0.041560  0.023622
# 1                   0.827586  0.879845  0.958440  0.976378
# chi-square value, p value, expected counts
# (79.79053093802577, 3.4038170553601627e-17, 3, array([[   3.89816701,   11.56008147,   87.32790224,   51.21384929],
#        [  83.10183299,  246.43991853, 1861.67209776, 1091.78615071]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF32FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF32FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF32FREQResponse'],data4['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                         41        73       130        27
# 1                         77       231       957       505
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF32FREQResponse
# 0                   0.347458  0.240132  0.119595  0.050752
# 1                   0.652542  0.759868  0.880405  0.949248
# chi-square value, p value, expected counts
# (110.38134346372925, 9.083769034261128e-24, 3, array([[ 15.6678099 ,  40.36452719, 144.32974032,  70.63792259],
#        [102.3321901 , 263.63547281, 942.67025968, 461.36207741]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF32FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF32FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF32FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF33FREQResponse'],data3['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                         21        55       304        98
# 1                         66       203      1645      1045
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.241379  0.213178  0.155977  0.085739
# 1                   0.758621  0.786822  0.844023  0.914261
# chi-square value, p value, expected counts
# (51.24416101992484, 4.339841604518106e-11, 3, array([[  12.09950538,   35.88129182,  271.05673553,  158.96246727],
#        [  74.90049462,  222.11870818, 1677.94326447,  984.03753273]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF33FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF33FREQResponse'],data4['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                         56       142       342       127
# 1                         62       162       745       405
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF33FREQResponse
# 0                   0.474576  0.467105  0.314627  0.238722
# 1                   0.525424  0.532895  0.685373  0.761278
# chi-square value, p value, expected counts
# (58.406167154246354, 1.2873153278306395e-12, 3, array([[ 38.56246938,  99.34737874, 355.2322391 , 173.85791279],
#        [ 79.43753062, 204.65262126, 731.7677609 , 358.14208721]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF33FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF33FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF33FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF34FREQResponse'],data3['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                         36        87       444       173
# 1                         51       171      1505       970
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.413793  0.337209  0.227809  0.151356
# 1                   0.586207  0.662791  0.772191  0.848644
# chi-square value, p value, expected counts
# (72.45193676354359, 1.2738013208123994e-15, 3, array([[  18.73145185,   55.54844341,  419.62758219,  246.09252255],
#        [  68.26854815,  202.45155659, 1529.37241781,  896.90747745]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF34FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF34FREQResponse'],data4['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                         77       160       455       163
# 1                         41       144       632       369
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF34FREQResponse
# 0                   0.652542  0.526316  0.418583  0.306391
# 1                   0.347458  0.473684  0.581417  0.693609
# chi-square value, p value, expected counts
# (68.53610024421803, 8.783714492230736e-15, 3, array([[ 49.43165115, 127.34933856, 455.35766781, 222.86134248],
#        [ 68.56834885, 176.65066144, 631.64233219, 309.13865752]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF34FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF34FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF34FREQResponse')

# %%
ct1=pd.crosstab(data3['H1PF36FREQResponse'],data3['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                         19        38        76        25
# 1                         68       220      1873      1118
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.218391  0.147287  0.038994  0.021872
# 1                   0.781609  0.852713  0.961006  0.978128
# chi-square value, p value, expected counts
# (136.6574102312501, 1.986647789300949e-29, 3, array([[   3.9994181 ,   11.86034332,   89.59615944,   52.54407914],
#        [  83.0005819 ,  246.13965668, 1859.40384056, 1090.45592086]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF36FREQResponse", data=data3, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(-5.950000000000003, 0.5, 'H1PF36FREQResponse')

# %%
ct1=pd.crosstab(data4['H1PF36FREQResponse'],data4['H1ED20FREQ'])
print(ct1)
colsum=ct1.sum(axis=0)
colpct=ct1/colsum
print(colpct)
print('chi-square value, p value, expected counts')
cs1=scipy.stats.chi2_contingency(ct1)
print(cs1)
# Out:
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                         47        80       130        38
# 1                         71       224       957       494
# H1ED20FREQ          1.000000  2.000000  4.000000  5.000000
# H1PF36FREQResponse
# 0                   0.398305  0.263158  0.119595  0.071429
# 1                   0.601695  0.736842  0.880405  0.928571
# chi-square value, p value, expected counts
# (124.51850968517651, 8.206404296047302e-27, 3, array([[ 17.05536502,  43.93924547, 157.11170995,  76.89367957],
#        [100.94463498, 260.06075453, 929.88829005, 455.10632043]]))

# %%
sns.factorplot(x="H1ED20FREQ", y="H1PF36FREQResponse", data=data4, kind='point', ci=None)
plt.xlabel('H1ED20FREQ')
plt.ylabel('H1PF36FREQResponse')
# Out:
# /home/ankita/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.42499999999999716, 0.5, 'H1PF36FREQResponse')
